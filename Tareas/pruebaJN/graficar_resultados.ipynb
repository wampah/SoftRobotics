# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

df=pd.read_csv('testb.csv')
df['psi']=df['Pressure']/6894.76
plt.plot(df['psi'],df['tipZ'])
plt.xlabel('Pressure (psi)')
plt.ylabel('tip Z(mm)')
# Out:
# Text(0, 0.5, 'tip Z(mm)')
